# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sb
import matplotlib.pyplot as plt
import matplotlib.cm as cmx
import matplotlib.colors as colors
import math
import pylab
import scipy.stats as stats
# %matplotlib inline

# %%
cols = [
    'id',
    'listing_url',
    'name',
    'latitude',
    'longitude',
    'neighbourhood_cleansed',
    'property_type',
    'room_type',
    'accommodates',
    'bedrooms',
    'bathrooms',
    'beds',
    'bed_type',
    'amenities',
    'price',
    'minimum_nights',
    'availability_365',
    'reviews_per_month',
    'review_scores_rating',
]

data = pd.read_csv('paris.csv', usecols=cols)

# %%
data.head()
# Out:
#      id                        listing_url                               name  \
# 0  3109  https://www.airbnb.com/rooms/3109                       zen and calm
# 1  5396  https://www.airbnb.com/rooms/5396     Explore the heart of old Paris
# 2  7397  https://www.airbnb.com/rooms/7397   MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 3  7964  https://www.airbnb.com/rooms/7964  Large & sunny flat with balcony !
# 4  8522  https://www.airbnb.com/rooms/8522            GREAT FLAT w/ CITY VIEW
#
#   neighbourhood_cleansed  latitude  longitude property_type        room_type  \
# 0           Observatoire  48.83349    2.31852     Apartment  Entire home/apt
# 1         Hôtel-de-Ville  48.85100    2.35869     Apartment  Entire home/apt
# 2         Hôtel-de-Ville  48.85758    2.35275     Apartment  Entire home/apt
# 3                  Opéra  48.87464    2.34341     Apartment  Entire home/apt
# 4           Ménilmontant  48.86528    2.39326     Apartment  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds       bed_type  \
# 0             2        1.0       0.0   1.0       Real Bed
# 1             2        1.0       0.0   1.0  Pull-out Sofa
# 2             4        1.0       2.0   2.0       Real Bed
# 3             2        1.0       1.0   1.0       Real Bed
# 4             3        1.0       1.0   1.0       Real Bed
#
#                                            amenities    price  minimum_nights  \
# 0  {Internet,Wifi,Kitchen,"Paid parking off premi...   $60.00               2
# 1  {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...  $115.00               1
# 2  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...  $119.00              10
# 3  {TV,"Cable TV",Internet,Wifi,Kitchen,"Buzzer/w...  $130.00               6
# 4  {Internet,Wifi,Kitchen,"Washer / Dryer",Elevat...   $90.00               3
#
#    availability_365  review_scores_rating  reviews_per_month
# 0               246                 100.0               0.24
# 1                70                  90.0               1.51
# 2               257                  94.0               2.45
# 3               352                  96.0               0.05
# 4               255                 100.0               0.01

# %%
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum())/data.isnull().count().sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total','Percent'], sort=False).sort_values('Total', ascending=False)
missing_data.head(40)
# Out:
#                         Total   Percent
# review_scores_rating    14386  0.221425
# reviews_per_month       13285  0.204479
# beds                      443  0.006819
# bedrooms                   80  0.001231
# name                       66  0.001016
# bathrooms                  57  0.000877
# property_type               0  0.000000
# listing_url                 0  0.000000
# availability_365            0  0.000000
# neighbourhood_cleansed      0  0.000000
# latitude                    0  0.000000
# longitude                   0  0.000000
# minimum_nights              0  0.000000
# room_type                   0  0.000000
# accommodates                0  0.000000
# price                       0  0.000000
# amenities                   0  0.000000
# bed_type                    0  0.000000
# id                          0  0.000000

# %%
# remove NaN values from dataframe
original = len(data)

data = data.dropna(how='any', subset=['name', 'bathrooms', 'bedrooms', 'beds'])

# convert formatting for price
data['price'] = (data['price'].str.replace(r'[^-+\d.]', '').astype(float))

# drop any inconsistent values
print('Number of Accommodates 0:', len(data[data['accommodates'] == 0]))
print('Number of Bedrooms 0:', len(data[data['bedrooms'] == 0]))
print('Number of Beds 0:', len(data[data['beds'] == 0]))
print('Number of Listings with Price $0.00:', len(data[data['price'] == 0.00]))

data = data[data['accommodates'] != 0]
data = data[data['bedrooms'] != 0]
data = data[data['beds'] != 0]
data = data[data['price'] != 0.00]

# convert amenities
# data['amenities'] = data['amenities'].apply(lambda x: len(x.split(',')))

print('Number of original values:', original)
print('Number of NaN values removed:', original - len(data))
print('Number of listings:', len(data))
# Out:
# Number of Accommodates 0: 0
# Number of Bedrooms 0: 13360
# Number of Beds 0: 1346
# Number of Listings with Price $0.00: 8
# Number of original values: 64970
# Number of NaN values removed: 14778
# Number of listings: 50192

# %%
# turn NaN scores with 0 reviews into 'No Reviews'
idx_vals = data['review_scores_rating'][data['reviews_per_month'] == 0].index.values.tolist()
data.loc[idx_vals, ('review_scores_rating')] = data['review_scores_rating'].fillna("No Reviews", inplace=True)
data.loc[idx_vals, ('reviews_per_month')] = data['reviews_per_month'].fillna(0, inplace=True)

# %%
data.head()
# Out:
#      id                        listing_url  \
# 2  7397  https://www.airbnb.com/rooms/7397
# 3  7964  https://www.airbnb.com/rooms/7964
# 4  8522  https://www.airbnb.com/rooms/8522
# 5  9359  https://www.airbnb.com/rooms/9359
# 6  9952  https://www.airbnb.com/rooms/9952
#
#                                               name neighbourhood_cleansed  \
# 2                 MARAIS - 2ROOMS APT - 2/4 PEOPLE         Hôtel-de-Ville
# 3                Large & sunny flat with balcony !                  Opéra
# 4                          GREAT FLAT w/ CITY VIEW           Ménilmontant
# 5  Cozy, Central Paris: WALK or VELIB EVERYWHERE !                 Louvre
# 6                        Paris petit coin douillet             Popincourt
#
#    latitude  longitude property_type        room_type  accommodates  \
# 2  48.85758    2.35275     Apartment  Entire home/apt             4
# 3  48.87464    2.34341     Apartment  Entire home/apt             2
# 4  48.86528    2.39326     Apartment  Entire home/apt             3
# 5  48.85899    2.34735     Apartment  Entire home/apt             2
# 6  48.86227    2.37134     Apartment  Entire home/apt             2
#
#    bathrooms  bedrooms  beds  bed_type  \
# 2        1.0       2.0   2.0  Real Bed
# 3        1.0       1.0   1.0  Real Bed
# 4        1.0       1.0   1.0  Real Bed
# 5        1.0       1.0   1.0  Real Bed
# 6        1.0       1.0   1.0  Real Bed
#
#                                            amenities  price  minimum_nights  \
# 2  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...  119.0              10
# 3  {TV,"Cable TV",Internet,Wifi,Kitchen,"Buzzer/w...  130.0               6
# 4  {Internet,Wifi,Kitchen,"Washer / Dryer",Elevat...   90.0               3
# 5  {Internet,Wifi,Kitchen,Elevator,Heating,Essent...   75.0             180
# 6  {TV,Internet,Wifi,Kitchen,"Paid parking off pr...   75.0               5
#
#    availability_365 review_scores_rating  reviews_per_month
# 2               257                   94               2.45
# 3               352                   96               0.05
# 4               255                  100               0.01
# 5               169           No Reviews               0.00
# 6               336                   98               0.25

# %%
# read to csv
data.to_csv('paris_pre.csv', index=False)
